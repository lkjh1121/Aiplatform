# %%
import pandas as pd

# %% [markdown]
# # 0.

# %%
df1 = pd.read_csv('gamedate_list.csv')
df2 = pd.read_csv('gameid_list.csv')
df3 = pd.read_csv('gamematchup_list.csv')
df4 = pd.read_csv('gamewl_list.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 df1 = pd.read_csv('gamedate_list.csv')
#       2 df2 = pd.read_csv('gameid_list.csv')
#       3 df3 = pd.read_csv('gamematchup_list.csv')
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
# ...

# %%
df_total = pd.concat([df1,df2,df3,df4],axis=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [7], line 1
# ----> 1 df_total = pd.concat([df1,df2,df3,df4],axis=1)
#
# NameError: name 'df1' is not defined

# %%
game_list = []
for i,j in zip(df1['GAME_DATE'],df3['MATCHUP']):
   i = pd.read_csv(f'{i}{j}.csv')[['TEAM_CITY','PLAYER_NAME','START_POSITION']]
   game_list.append(i)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [8], line 2
#       1 game_list = []
# ----> 2 for i,j in zip(df1['GAME_DATE'],df3['MATCHUP']):
#       3    i = pd.read_csv(f'{i}{j}.csv')[['TEAM_CITY','PLAYER_NAME','START_POSITION']]
#       4    game_list.append(i)
#
# NameError: name 'df1' is not defined

# %%
game_list[40]
# Out:
#      TEAM_CITY               PLAYER_NAME START_POSITION
# 0   Washington  Kentavious Caldwell-Pope              F
# 1   Washington             Rui Hachimura              F
# 2   Washington        Kristaps Porzingis              C
# 3   Washington             Corey Kispert              G
# 4   Washington                 Raul Neto              G
# 5   Washington               Deni Avdija            NaN
# 6   Washington                 Ish Smith            NaN
# 7   Washington          Tomas Satoransky            NaN
# 8   Washington            Daniel Gafford            NaN
# 9   Washington              Anthony Gill            NaN
# 10  Washington             Thomas Bryant            NaN
# 11  Washington               Isaiah Todd            NaN
# 12   Milwaukee           Wesley Matthews              F
# 13   Milwaukee              Bobby Portis              F
# 14   Milwaukee               Brook Lopez              C
# 15   Milwaukee             Grayson Allen              G
# ...

# %%
game_list[3].TEAM_CITY.unique()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [9], line 1
# ----> 1 game_list[3].TEAM_CITY.unique()
#
# IndexError: list index out of range

# %%
Milwaukee = game_list[1].query('TEAM_CITY == "Milwaukee"').PLAYER_NAME.to_list()
Minnesota = game_list[1].query('TEAM_CITY == "Minnesota"').PLAYER_NAME.to_list()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 Milwaukee = game_list[1].query('TEAM_CITY == "Milwaukee"').PLAYER_NAME.to_list()
#       2 Minnesota = game_list[1].query('TEAM_CITY == "Minnesota"').PLAYER_NAME.to_list()
#
# IndexError: list index out of range

# %%
Milwaukee22_23 = pd.read_csv('../팀 소속 멤버 스텟/동부/22_23/Milwaukee Bucks22_23.csv')
Minnesota22_23 = pd.read_csv('../팀 소속 멤버 스텟/서부/22_23/Minnesota Timberwolves22_23.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In [11], line 1
# ----> 1 Milwaukee22_23 = pd.read_csv('../팀 소속 멤버 스텟/동부/22_23/Milwaukee Bucks22_23.csv')
#       2 Minnesota22_23 = pd.read_csv('../팀 소속 멤버 스텟/서부/22_23/Minnesota Timberwolves22_23.csv')
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File c:\Users\ASUS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
# ...

# %%
Milwaukee = pd.DataFrame(Milwaukee)
Minnesota = pd.DataFrame(Minnesota)

# %%
Milwaukee22_23 = Milwaukee22_23[['team','status']]
Minnesota22_23 = Minnesota22_23[['team','status']]

# %%
MilwaukeeMe = pd.merge(left = Milwaukee, right = Milwaukee22_23,left_on=0,right_on='team')
MinnesotaMe = pd.merge(left = Minnesota, right = Minnesota22_23,left_on=0,right_on='team')

# %%
MilwaukeeMe = MilwaukeeMe.drop(columns=[0,'team'])
MinnesotaMe = MinnesotaMe.drop(columns=[0,'team']).T

# %%
MilwaukeeMe
# Out:
#     status
# 0       75
# 1       97
# 2       80
# 3       72
# 4       86
# 5       80
# 6       73
# 7       72
# 8       71
# 9       72
# 10      75

# %%
Milwaukee22_23 = pd.read_csv('../팀 소속 멤버 스텟/동부/22_23/Milwaukee Bucks22_23.csv')
Minnesota22_23 = pd.read_csv('../팀 소속 멤버 스텟/서부/22_23/Minnesota Timberwolves22_23.csv')

# %%
Milwaukee22_23 = Milwaukee22_23[['team','status']]
Minnesota22_23 = Minnesota22_23[['team','status']]

# %%
MilwaukeeMe = pd.merge(left = Milwaukee, right = Milwaukee22_23,left_on=0,right_on='team')
MinnesotaMe = pd.merge(left = Minnesota, right = Minnesota22_23,left_on=0,right_on='team')

# %%
temp = pd.read_csv('../팀 스텟/team22_23.csv')

# %%
temp
# Out:
#     Unnamed: 0                    team  status
# 0            0          Boston Celtics    78.6
# 1            1    New Orleans Pelicans    77.4
# 2            2     Cleveland Cavaliers    77.2
# 3            3            Phoenix Suns    77.0
# 4            4           Atlanta Hawks    76.8
# 5            5           Brooklyn Nets    76.5
# 6            6           Chicago Bulls    76.4
# 7            7    Los Angeles Clippers    76.4
# 8            8   Golden State Warriors    76.3
# 9            9              Miami Heat    76.2
# 10          10      Philadelphia 76ers    76.2
# 11          11         Milwaukee Bucks    76.1
# 12          12      Washington Wizards    76.1
# 13          13          Indiana Pacers    75.9
# 14          14        Sacramento Kings    75.9
# 15          15         New York Knicks    75.8
# 16          16  Minnesota Timberwolves    75.7
# 17          17       Charlotte Hornets    75.6
# 18          18        Dallas Mavericks    75.3
# ...

# %%
from nba_api.stats.endpoints import BoxScoreTraditionalV2

# %%
df = BoxScoreTraditionalV2(game_id='2052200018')

# %%
df.get_data_frames()[0]
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0   2052200018  1612709919               WES  Westchester    1629051
# 1   2052200018  1612709919               WES  Westchester    1631365
# 2   2052200018  1612709919               WES  Westchester    1630624
# 3   2052200018  1612709919               WES  Westchester    1631211
# 4   2052200018  1612709919               WES  Westchester    1631231
# 5   2052200018  1612709919               WES  Westchester    1630640
# 6   2052200018  1612709919               WES  Westchester    1629245
# 7   2052200018  1612709919               WES  Westchester    1629789
# 8   2052200018  1612709919               WES  Westchester    1631378
# 9   2052200018  1612709919               WES  Westchester    1631376
# 10  2052200018  1612709915               MNE        Maine    1629621
# 11  2052200018  1612709915               MNE        Maine    1629677
# 12  2052200018  1612709915               MNE        Maine    1629662
# ...
